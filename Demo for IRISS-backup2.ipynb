# %% [markdown]
# # Importing Modules
#
# The necessary modules are : os, opencv, numpy, tqdm, matplotlib, keras and sklearn

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, BatchNormalization, Activation, add
from keras.models import Model, model_from_json
from keras.optimizers import Adam
from keras.layers.advanced_activations import ELU, LeakyReLU
from keras.utils.vis_utils import plot_model
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras2onnx import convert_keras
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# check if GPU is available
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
K.tensorflow_backend._get_available_gpus()
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13218341143350871406
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 9978406503
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2165525177736396820
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %% [markdown]
# # Constructing Training and Test Datasets

# %% [markdown]
# ## Loading the Images
#
# We first load all the images and the corresponding segmentation masks.
#
# They are stored in two lists X, Y and respectively
#
# Moreover, the images are resized to 256x192

# %%
X = []
Y = []
n_classes = 5
 
for scan_dir in ['scan30','scan31','scan32']:
    image_idx = 0

    img_dir = "E:\YKL\Thorlabs VSCAN Labeling\{}".format(scan_dir)
    label_dir = "E:\YKL\Thorlabs VSCAN Labeling\{}\LabelingProject\GroundTruthProject\PixelLabelData".format(scan_dir)

    img_files = next(os.walk(img_dir))[2]
    msk_files = next(os.walk(label_dir))[2]

    img_files.sort()
    msk_files.sort()

    print(len(img_files))
    print(len(msk_files))

    for img_fl in tqdm(img_files):    
        if(img_fl.split('.')[-1]=='png'):
            image_idx += 1

            img = cv2.imread('{}\{}'.format(img_dir,img_fl), cv2.IMREAD_GRAYSCALE)

    #         print('E:\YKL\Thorlabs VSCAN Labeling\scan30\{}'.format(img_fl))
            resized_img = cv2.equalizeHist(np.clip(cv2.resize(img,(400, 352), interpolation = cv2.INTER_NEAREST),0,255))
            resized_denoised_img = cv2.fastNlMeansDenoising(resized_img,10,7,21)

            X.append(resized_denoised_img)

            msk = cv2.imread('{}\Label_{}_{}'.format(label_dir,image_idx,img_fl.split('.')[0]+'.png'), cv2.IMREAD_GRAYSCALE)
            resized_msk = np.clip(cv2.resize(msk,(400, 352), interpolation = cv2.INTER_NEAREST),0,4)

            # additional post processing for one hot encoding mask
            resized_msk[resized_msk==0] = 6;
            resized_msk_one_hot = np.zeros((resized_msk.shape[0], resized_msk.shape[1], n_classes)) 5
            for i, unique_value in enumerate(np.unique(resized_msk)):
                resized_msk_one_hot[:, :, i][resized_msk == unique_value] = 1

            Y.append(resized_msk_one_hot)
# Out:
# 64
# 63
# 100%|██████████| 64/64 [00:31<00:00,  2.04it/s]
# 76
# 76
# 100%|██████████| 76/76 [00:38<00:00,  1.99it/s]
# 68
# 68
# 100%|██████████| 68/68 [00:33<00:00,  2.01it/s]

# %% [markdown]
# ## Testing different variations of preprocessing

# %%
# uncomment for testing

# img = cv2.imread('E:\YKL\Thorlabs VSCAN Labeling\scan30\VSCAN_0030_150.png', cv2.IMREAD_GRAYSCALE)
# # plt.subplot(1,4,1)
# # plt.imshow(img)
# plt.figure(figsize=(20,10))
# plt.subplot(1,3,1)
# img2 = np.clip(cv2.resize(cv2.fastNlMeansDenoising(img2,200,7,21),(400, 352), interpolation = cv2.INTER_NEAREST),0,255)
# plt.imshow(img2)

# plt.subplot(1,3,2)
# img2 = cv2.equalizeHist(img2)
# plt.imshow(img2)

# # plt.subplot(1,3,3)
# # img2 = cv2.fastNlMeansDenoising(img2,200,7,21)
# # plt.imshow(img2)

# %% [markdown]
# ## Train-Test Split
#
# The X, Y lists are converted to numpy arrays for convenience.
# Furthermore, the images are divided by 255 to bring down the pixel values to [0...1] range. On the other hand the segmentations masks are converted to binary (0 or 1) values.
#
# Using Sklearn *train_test_split* we split the data randomly into 80% training and 20% testing data

# %%
print(len(X))
print(len(Y))

X = np.array(X)
X = X[:, :, :, np.newaxis]
Y = np.array(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

Y_train = Y_train.reshape((Y_train.shape[0],Y_train.shape[1],Y_train.shape[2],n_classes))
Y_test = Y_test.reshape((Y_test.shape[0],Y_test.shape[1],Y_test.shape[2],n_classes))

X_train = X_train / 255
X_test = X_test / 255
Y_train = Y_train
Y_test = Y_test

Y_train = np.round(Y_train,0)
Y_test = np.round(Y_test,0)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# 207
# 207
# (165, 352, 400, 1)
# (165, 352, 400, 5)
# (42, 352, 400, 1)
# (42, 352, 400, 5)

# %% [markdown]
# ## Display one image from test

# %%
# %matplotlib inline
plt.imshow(Y_test[1][:,:,1])

# %% [markdown]
# ## Form segmented images from one hot encoding

# %%
def one_hot_to_seg(img_lst_one_hot):
    img_lst_new = []
    for one_hot_img in range(len(img_lst_one_hot)):
        img_new = np.copy(img_lst_one_hot[one_hot_img])
        for lbl in range(0,5):
            img_new[:,:,lbl]*=lbl*255/5
        img_lst_new.append(np.sum(img_new,axis=2))
    return img_lst_new

# %%
Y_test_disp = one_hot_to_seg(Y_test)

# %% [markdown]
# # MultiResUNet Model

# %% [markdown]
# ## Model Definition
#
# The MultiResUNet model as described in the [paper](https://arxiv.org/abs/1902.04049) can be found  [here](https://github.com/nibtehaz/MultiResUNet/blob/master/MultiResUNet.py)

# %%
def conv2d_bn(x, filters, num_row, num_col, padding='same', strides=(1, 1), activation='relu', name=None):
    '''
    2D Convolutional layers
    
    Arguments:
        x {keras layer} -- input layer 
        filters {int} -- number of filters
        num_row {int} -- number of rows in filters
        num_col {int} -- number of columns in filters
    
    Keyword Arguments:
        padding {str} -- mode of padding (default: {'same'})
        strides {tuple} -- stride of convolution operation (default: {(1, 1)})
        activation {str} -- activation function (default: {'relu'})
        name {str} -- name of the layer (default: {None})
    
    Returns:
        [keras layer] -- [output layer]
    '''

    x = Conv2D(filters, (num_row, num_col), strides=strides, padding=padding, use_bias=False)(x)
    x = BatchNormalization(axis=3, scale=False)(x)

    if(activation == None):
        return x

    x = Activation(activation, name=name)(x)

    return x


def trans_conv2d_bn(x, filters, num_row, num_col, padding='same', strides=(2, 2), name=None):
    '''
    2D Transposed Convolutional layers
    
    Arguments:
        x {keras layer} -- input layer 
        filters {int} -- number of filters
        num_row {int} -- number of rows in filters
        num_col {int} -- number of columns in filters
    
    Keyword Arguments:
        padding {str} -- mode of padding (default: {'same'})
        strides {tuple} -- stride of convolution operation (default: {(2, 2)})
        name {str} -- name of the layer (default: {None})
    
    Returns:
        [keras layer] -- [output layer]
    '''

    x = Conv2DTranspose(filters, (num_row, num_col), strides=strides, padding=padding)(x)
    x = BatchNormalization(axis=3, scale=False)(x)
    
    return x


def MultiResBlock(U, inp, alpha = 1.67):
    '''
    MultiRes Block
    
    Arguments:
        U {int} -- Number of filters in a corrsponding UNet stage
        inp {keras layer} -- input layer 
    
    Returns:
        [keras layer] -- [output layer]
    '''

    W = alpha * U

    shortcut = inp

    shortcut = conv2d_bn(shortcut, int(W*0.167) + int(W*0.333) +
                         int(W*0.5), 1, 1, activation=None, padding='same')

    conv3x3 = conv2d_bn(inp, int(W*0.167), 3, 3,
                        activation='relu', padding='same')

    conv5x5 = conv2d_bn(conv3x3, int(W*0.333), 3, 3,
                        activation='relu', padding='same')

    conv7x7 = conv2d_bn(conv5x5, int(W*0.5), 3, 3,
                        activation='relu', padding='same')

    out = concatenate([conv3x3, conv5x5, conv7x7], axis=3)
    out = BatchNormalization(axis=3)(out)

    out = add([shortcut, out])
    out = Activation('relu')(out)
    out = BatchNormalization(axis=3)(out)

    return out


def ResPath(filters, length, inp):
    '''
    ResPath
    
    Arguments:
        filters {int} -- [description]
        length {int} -- length of ResPath
        inp {keras layer} -- input layer 
    
    Returns:
        [keras layer] -- [output layer]
    '''


    shortcut = inp
    shortcut = conv2d_bn(shortcut, filters, 1, 1,
                         activation=None, padding='same')

    out = conv2d_bn(inp, filters, 3, 3, activation='relu', padding='same')

    out = add([shortcut, out])
    out = Activation('relu')(out)
    out = BatchNormalization(axis=3)(out)

    for i in range(length-1):

        shortcut = out
        shortcut = conv2d_bn(shortcut, filters, 1, 1,
                             activation=None, padding='same')

        out = conv2d_bn(out, filters, 3, 3, activation='relu', padding='same')

        out = add([shortcut, out])
        out = Activation('relu')(out)
        out = BatchNormalization(axis=3)(out)

    return out


def MultiResUnet(height, width, n_channels):
    '''
    MultiResUNet
    
    Arguments:
        height {int} -- height of image 
        width {int} -- width of image 
        n_channels {int} -- number of channels in image
    
    Returns:
        [keras model] -- MultiResUNet model
    '''


    inputs = Input((height, width, n_channels))

    mresblock1 = MultiResBlock(32, inputs)
    pool1 = MaxPooling2D(pool_size=(2, 2))(mresblock1)
    mresblock1 = ResPath(32, 4, mresblock1)

    mresblock2 = MultiResBlock(32*2, pool1)
    pool2 = MaxPooling2D(pool_size=(2, 2))(mresblock2)
    mresblock2 = ResPath(32*2, 3, mresblock2)

    mresblock3 = MultiResBlock(32*4, pool2)
    pool3 = MaxPooling2D(pool_size=(2, 2))(mresblock3)
    mresblock3 = ResPath(32*4, 2, mresblock3)

    mresblock4 = MultiResBlock(32*8, pool3)
    pool4 = MaxPooling2D(pool_size=(2, 2))(mresblock4)
    mresblock4 = ResPath(32*8, 1, mresblock4)

    mresblock5 = MultiResBlock(32*16, pool4)

    up6 = concatenate([Conv2DTranspose(
        32*8, (2, 2), strides=(2, 2), padding='same')(mresblock5), mresblock4], axis=3)
    mresblock6 = MultiResBlock(32*8, up6)

    up7 = concatenate([Conv2DTranspose(
        32*4, (2, 2), strides=(2, 2), padding='same')(mresblock6), mresblock3], axis=3)
    mresblock7 = MultiResBlock(32*4, up7)

    up8 = concatenate([Conv2DTranspose(
        32*2, (2, 2), strides=(2, 2), padding='same')(mresblock7), mresblock2], axis=3)
    mresblock8 = MultiResBlock(32*2, up8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(
        2, 2), padding='same')(mresblock8), mresblock1], axis=3)
    mresblock9 = MultiResBlock(32, up9)

    conv10 = conv2d_bn(mresblock9, 5, 1, 1, activation='sigmoid')
    
    model = Model(inputs=[inputs], outputs=[conv10])

    return model

# %% [markdown]
# ## Auxiliary Functions

# %% [markdown]
# ### Custom Metrics
#
# Since Keras does not have build-in support for computing Dice Coefficient or Jaccard Index (at the time of writing), the following functions are declared

# %%
# def dice_coef(y_true, y_pred):
#     smooth = 0.0
#     y_true_f = K.flatten(y_true)
#     y_pred_f = K.flatten(y_pred)
#     intersection = K.sum(y_true_f * y_pred_f)
#     return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# def jacard(y_true, y_pred):

#     y_true_f = K.flatten(y_true)
#     y_pred_f = K.flatten(y_pred)
#     intersection = K.sum ( y_true_f * y_pred_f)
#     union = K.sum ( y_true_f + y_pred_f - y_true_f * y_pred_f)

#     return intersection/union

# %% [markdown]
# ### Saving Model
#
# Function to save the model

# %%
def saveModel(model):

    model_json = model.to_json()

    try:
        os.makedirs('models')
    except:
        pass
    
    fp = open('models/modelP.json','w')
    fp.write(model_json)
    model.save_weights('models/modelW.h5')

# %% [markdown]
# ### Evaluate the Model
#
# We evaluate the model on test data (X_test, Y_test).
#
# We compute the values of Jaccard Index and Dice Coeficient, and save the predicted segmentation of first 10 images. The best model is also saved
#
# (This could have been done using keras call-backs as well)

# %%
def evaluateModel(model, X_test, Y_test, batchSize):
    
    try:
        os.makedirs('results')
    except:
        pass 
    

    yp = model.predict(x=X_test, batch_size=batchSize, verbose=1)

    yp = np.round(yp,0)
    
    yp_disp = one_hot_to_seg(yp)

    for i in range(10):

        plt.figure(figsize=(20,10))
        plt.subplot(1,3,1)
        plt.imshow(np.squeeze(X_test[i],axis=2))
        plt.title('Input')
        plt.subplot(1,3,2)
        #TODO: show segmented Y
        plt.imshow(Y_test_disp[i].reshape(Y_test[i].shape[0],Y_test[i].shape[1]))
        plt.title('Ground Truth')
        plt.subplot(1,3,3)
        plt.imshow(yp_disp[i].reshape(yp[i].shape[0],yp[i].shape[1]))
        plt.title('Prediction')

        intersection = yp[i].ravel() * Y_test[i].ravel()
        union = yp[i].ravel() + Y_test[i].ravel() - intersection

        jacard = (np.sum(intersection)/np.sum(union))  
        plt.suptitle('Jacard Index'+ str(np.sum(intersection)) +'/'+ str(np.sum(union)) +'='+str(jacard))

        plt.savefig('results/'+str(i)+'.png',format='png')
        plt.close()


    jacard = 0
    dice = 0
    
    
    for i in range(len(Y_test)):
        yp_2 = yp[i].ravel()
        y2 = Y_test[i].ravel()
        
        intersection = yp_2 * y2
        union = yp_2 + y2 - intersection

        jacard += (np.sum(intersection)/np.sum(union))  

        dice += (2. * np.sum(intersection) ) / (np.sum(yp_2) + np.sum(y2))

    
    jacard /= len(Y_test)
    dice /= len(Y_test)
    


    print('Jacard Index : '+str(jacard))
    print('Dice Coefficient : '+str(dice))
    

    fp = open('models/log.txt','a')
    fp.write(str(jacard)+'\n')
    fp.close()

    fp = open('models/best.txt','r')
    best = fp.read()
    fp.close()

    if(jacard>float(best)):
        print('***********************************************')
        print('Jacard Index improved from '+str(best)+' to '+str(jacard))
        print('***********************************************')
        fp = open('models/best.txt','w')
        fp.write(str(jacard))
        fp.close()

        saveModel(model)

# %% [markdown]
# ### Training the Model
#
# The model is trained and evaluated after each epochs

# %%
def trainStep(model, X_train, Y_train, X_test, Y_test, epochs, batchSize):

    
    for epoch in range(epochs):
        print('Epoch : {}'.format(epoch+1))
        model.fit(x=X_train, y=Y_train, batch_size=batchSize, epochs=1, verbose=1)     

        evaluateModel(model,X_test, Y_test,batchSize)

    return model

# %% [markdown]
# ## Define Model, Train and Evaluate

# %%
model = MultiResUnet(height=352, width=400, n_channels=1)

# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[dice_coef, jacard, 'categorical_accuracy'])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['categorical_accuracy'])

saveModel(model)

fp = open('models/log.txt','w')
fp.close()
fp = open('models/best.txt','w')
fp.write('-1.0')
fp.close()
    
trainStep(model, X_train, Y_train, X_test, Y_test, epochs=60, batchSize=3)
# trainStep(model, X_train, Y_train, X_test, Y_test, epochs=2, batchSize=3)
# Out:
# WARNING:tensorflow:From c:\Users\Computer\anaconda3\envs\multiresunet2\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Users\Computer\anaconda3\envs\multiresunet2\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\Computer\anaconda3\envs\multiresunet2\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch : 1
# WARNING:tensorflow:From c:\Users\Computer\anaconda3\envs\multiresunet2\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/1
# 165/165 [==============================] - ETA: 18:42 - loss: 0.7931 - categorical_accuracy: 0.223 - ETA: 9:20 - loss: 0.7720 - categorical_accuracy: 0.255 - ETA: 6:12 - loss: 0.7573 - categorical_accuracy: 0.27 - ETA: 4:39 - loss: 0.7467 - categorical_accuracy: 0.28 - ETA: 3:42 - loss: 0.7377 - categorical_accuracy: 0.29 - ETA: 3:04 - loss: 0.7313 - categorical_accuracy: 0.30 - ETA: 2:37 - loss: 0.7253 - categorical_accuracy: 0.31 - ETA: 2:16 - loss: 0.7206 - categorical_accuracy: 0.32 - ETA: 2:01 - loss: 0.7170 - categorical_accuracy: 0.33 - ETA: 1:48 - loss: 0.7131 - categorical_accuracy: 0.34 - ETA: 1:37 - loss: 0.7092 - categorical_accuracy: 0.34 - ETA: 1:28 - loss: 0.7059 - categorical_accuracy: 0.35 - ETA: 1:21 - loss: 0.7028 - categorical_accuracy: 0.36 - ETA: 1:14 - loss: 0.6995 - categorical_accuracy: 0.37 - ETA: 1:09 - loss: 0.6964 - categorical_accuracy: 0.38 - ETA: 1:04 - loss: 0.6933 - categorical_accuracy: 0.38 - ETA: 59s - loss: 0.6904 - categorical_accuracy: 0.3963 - ETA: 55s - loss: 0.6872 - categorical_accuracy: 0.404 - ETA: 52s - loss: 0.6842 - categorical_accuracy: 0.412 - ETA: 48s - loss: 0.6811 - categorical_accuracy: 0.421 - ETA: 45s - loss: 0.6786 - categorical_accuracy: 0.428 - ETA: 43s - loss: 0.6760 - categorical_accuracy: 0.436 - ETA: 40s - loss: 0.6735 - categorical_accuracy: 0.444 - ETA: 38s - loss: 0.6710 - categorical_accuracy: 0.452 - ETA: 35s - loss: 0.6682 - categorical_accuracy: 0.460 - ETA: 33s - loss: 0.6656 - categorical_accuracy: 0.468 - ETA: 31s - loss: 0.6629 - categorical_accuracy: 0.478 - ETA: 29s - loss: 0.6605 - categorical_accuracy: 0.487 - ETA: 28s - loss: 0.6582 - categorical_accuracy: 0.497 - ETA: 26s - loss: 0.6562 - categorical_accuracy: 0.506 - ETA: 24s - loss: 0.6543 - categorical_accuracy: 0.514 - ETA: 23s - loss: 0.6525 - categorical_accuracy: 0.523 - ETA: 21s - loss: 0.6502 - categorical_accuracy: 0.533 - ETA: 20s - loss: 0.6481 - categorical_accuracy: 0.543 - ETA: 19s - loss: 0.6458 - categorical_accuracy: 0.553 - ETA: 17s - loss: 0.6438 - categorical_accuracy: 0.562 - ETA: 16s - loss: 0.6418 - categorical_accuracy: 0.571 - ETA: 15s - loss: 0.6397 - categorical_accuracy: 0.580 - ETA: 14s - loss: 0.6378 - categorical_accuracy: 0.589 - ETA: 13s - loss: 0.6358 - categorical_accuracy: 0.597 - ETA: 12s - loss: 0.6341 - categorical_accuracy: 0.605 - ETA: 11s - loss: 0.6323 - categorical_accuracy: 0.613 - ETA: 10s - loss: 0.6306 - categorical_accuracy: 0.620 - ETA: 9s - loss: 0.6288 - categorical_accuracy: 0.627 - ETA: 8s - loss: 0.6270 - categorical_accuracy: 0.63 - ETA: 7s - loss: 0.6252 - categorical_accuracy: 0.64 - ETA: 6s - loss: 0.6237 - categorical_accuracy: 0.64 - ETA: 5s - loss: 0.6221 - categorical_accuracy: 0.65 - ETA: 4s - loss: 0.6206 - categorical_accuracy: 0.65 - ETA: 3s - loss: 0.6191 - categorical_accuracy: 0.66 - ETA: 3s - loss: 0.6178 - categorical_accuracy: 0.67 - ETA: 2s - loss: 0.6163 - categorical_accuracy: 0.67 - ETA: 1s - loss: 0.6148 - categorical_accuracy: 0.68 - ETA: 0s - loss: 0.6136 - categorical_accuracy: 0.68 - 41s 246ms/step - loss: 0.6123 - categorical_accuracy: 0.6910
# 42/42 [==============================] - ETA: 15 - ETA: 7 - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 61ms/step
# Jacard Index : 0.04107588443071215
# Dice Coefficient : 0.07878118381287182
# ***********************************************
# Jacard Index improved from -1.0 to 0.04107588443071215
# ***********************************************
# Epoch : 2
# Epoch 1/1
# 165/165 [==============================] - ETA: 40s - loss: 0.5458 - categorical_accuracy: 0.949 - ETA: 31s - loss: 0.5462 - categorical_accuracy: 0.948 - ETA: 25s - loss: 0.5455 - categorical_accuracy: 0.950 - ETA: 23s - loss: 0.5445 - categorical_accuracy: 0.952 - ETA: 21s - loss: 0.5439 - categorical_accuracy: 0.953 - ETA: 20s - loss: 0.5423 - categorical_accuracy: 0.955 - ETA: 19s - loss: 0.5416 - categorical_accuracy: 0.955 - ETA: 18s - loss: 0.5413 - categorical_accuracy: 0.955 - ETA: 18s - loss: 0.5403 - categorical_accuracy: 0.956 - ETA: 17s - loss: 0.5405 - categorical_accuracy: 0.956 - ETA: 16s - loss: 0.5395 - categorical_accuracy: 0.957 - ETA: 16s - loss: 0.5393 - categorical_accuracy: 0.958 - ETA: 15s - loss: 0.5389 - categorical_accuracy: 0.957 - ETA: 15s - loss: 0.5385 - categorical_accuracy: 0.957 - ETA: 14s - loss: 0.5384 - categorical_accuracy: 0.957 - ETA: 14s - loss: 0.5383 - categorical_accuracy: 0.957 - ETA: 13s - loss: 0.5376 - categorical_accuracy: 0.958 - ETA: 13s - loss: 0.5375 - categorical_accuracy: 0.958 - ETA: 12s - loss: 0.5377 - categorical_accuracy: 0.958 - ETA: 12s - loss: 0.5372 - categorical_accuracy: 0.958 - ETA: 11s - loss: 0.5372 - categorical_accuracy: 0.958 - ETA: 11s - loss: 0.5368 - categorical_accuracy: 0.958 - ETA: 11s - loss: 0.5366 - categorical_accuracy: 0.958 - ETA: 10s - loss: 0.5364 - categorical_accuracy: 0.958 - ETA: 10s - loss: 0.5360 - categorical_accuracy: 0.959 - ETA: 10s - loss: 0.5356 - categorical_accuracy: 0.959 - ETA: 9s - loss: 0.5355 - categorical_accuracy: 0.959 - ETA: 9s - loss: 0.5356 - categorical_accuracy: 0.95 - ETA: 9s - loss: 0.5355 - categorical_accuracy: 0.95 - ETA: 8s - loss: 0.5352 - categorical_accuracy: 0.95 - ETA: 8s - loss: 0.5352 - categorical_accuracy: 0.95 - ETA: 7s - loss: 0.5353 - categorical_accuracy: 0.95 - ETA: 7s - loss: 0.5350 - categorical_accuracy: 0.95 - ETA: 7s - loss: 0.5347 - categorical_accuracy: 0.95 - ETA: 6s - loss: 0.5343 - categorical_accuracy: 0.96 - ETA: 6s - loss: 0.5340 - categorical_accuracy: 0.96 - ETA: 6s - loss: 0.5336 - categorical_accuracy: 0.96 - ETA: 5s - loss: 0.5334 - categorical_accuracy: 0.96 - ETA: 5s - loss: 0.5334 - categorical_accuracy: 0.95 - ETA: 5s - loss: 0.5332 - categorical_accuracy: 0.95 - ETA: 4s - loss: 0.5329 - categorical_accuracy: 0.95 - ETA: 4s - loss: 0.5326 - categorical_accuracy: 0.95 - ETA: 4s - loss: 0.5323 - categorical_accuracy: 0.96 - ETA: 3s - loss: 0.5319 - categorical_accuracy: 0.96 - ETA: 3s - loss: 0.5316 - categorical_accuracy: 0.96 - ETA: 3s - loss: 0.5313 - categorical_accuracy: 0.96 - ETA: 3s - loss: 0.5309 - categorical_accuracy: 0.96 - ETA: 2s - loss: 0.5307 - categorical_accuracy: 0.96 - ETA: 2s - loss: 0.5304 - categorical_accuracy: 0.96 - ETA: 2s - loss: 0.5303 - categorical_accuracy: 0.96 - ETA: 1s - loss: 0.5301 - categorical_accuracy: 0.96 - ETA: 1s - loss: 0.5299 - categorical_accuracy: 0.96 - ETA: 0s - loss: 0.5297 - categorical_accuracy: 0.96 - ETA: 0s - loss: 0.5295 - categorical_accuracy: 0.96 - 22s 136ms/step - loss: 0.5292 - categorical_accuracy: 0.9610
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 42ms/step
# Jacard Index : 0.03972936565487543
# Dice Coefficient : 0.07630201712508959
# Epoch : 3
# Epoch 1/1
# 165/165 [==============================] - ETA: 37s - loss: 0.5237 - categorical_accuracy: 0.956 - ETA: 31s - loss: 0.5188 - categorical_accuracy: 0.961 - ETA: 29s - loss: 0.5178 - categorical_accuracy: 0.963 - ETA: 26s - loss: 0.5162 - categorical_accuracy: 0.965 - ETA: 25s - loss: 0.5148 - categorical_accuracy: 0.967 - ETA: 24s - loss: 0.5146 - categorical_accuracy: 0.967 - ETA: 23s - loss: 0.5158 - categorical_accuracy: 0.966 - ETA: 22s - loss: 0.5158 - categorical_accuracy: 0.966 - ETA: 21s - loss: 0.5162 - categorical_accuracy: 0.965 - ETA: 20s - loss: 0.5167 - categorical_accuracy: 0.966 - ETA: 20s - loss: 0.5164 - categorical_accuracy: 0.966 - ETA: 19s - loss: 0.5158 - categorical_accuracy: 0.966 - ETA: 19s - loss: 0.5152 - categorical_accuracy: 0.966 - ETA: 23s - loss: 0.5150 - categorical_accuracy: 0.966 - ETA: 28s - loss: 0.5147 - categorical_accuracy: 0.966 - ETA: 27s - loss: 0.5144 - categorical_accuracy: 0.966 - ETA: 26s - loss: 0.5137 - categorical_accuracy: 0.966 - ETA: 25s - loss: 0.5131 - categorical_accuracy: 0.966 - ETA: 24s - loss: 0.5129 - categorical_accuracy: 0.966 - ETA: 23s - loss: 0.5126 - categorical_accuracy: 0.966 - ETA: 22s - loss: 0.5121 - categorical_accuracy: 0.966 - ETA: 21s - loss: 0.5119 - categorical_accuracy: 0.966 - ETA: 20s - loss: 0.5117 - categorical_accuracy: 0.966 - ETA: 19s - loss: 0.5117 - categorical_accuracy: 0.967 - ETA: 19s - loss: 0.5116 - categorical_accuracy: 0.967 - ETA: 19s - loss: 0.5112 - categorical_accuracy: 0.967 - ETA: 20s - loss: 0.5110 - categorical_accuracy: 0.967 - ETA: 19s - loss: 0.5106 - categorical_accuracy: 0.967 - ETA: 19s - loss: 0.5106 - categorical_accuracy: 0.967 - ETA: 18s - loss: 0.5102 - categorical_accuracy: 0.968 - ETA: 17s - loss: 0.5099 - categorical_accuracy: 0.968 - ETA: 16s - loss: 0.5097 - categorical_accuracy: 0.968 - ETA: 15s - loss: 0.5093 - categorical_accuracy: 0.968 - ETA: 14s - loss: 0.5090 - categorical_accuracy: 0.968 - ETA: 13s - loss: 0.5089 - categorical_accuracy: 0.968 - ETA: 13s - loss: 0.5087 - categorical_accuracy: 0.968 - ETA: 13s - loss: 0.5084 - categorical_accuracy: 0.968 - ETA: 13s - loss: 0.5082 - categorical_accuracy: 0.968 - ETA: 12s - loss: 0.5080 - categorical_accuracy: 0.968 - ETA: 11s - loss: 0.5078 - categorical_accuracy: 0.968 - ETA: 10s - loss: 0.5075 - categorical_accuracy: 0.968 - ETA: 9s - loss: 0.5073 - categorical_accuracy: 0.968 - ETA: 8s - loss: 0.5070 - categorical_accuracy: 0.96 - ETA: 7s - loss: 0.5069 - categorical_accuracy: 0.96 - ETA: 7s - loss: 0.5066 - categorical_accuracy: 0.96 - ETA: 6s - loss: 0.5065 - categorical_accuracy: 0.96 - ETA: 5s - loss: 0.5062 - categorical_accuracy: 0.96 - ETA: 5s - loss: 0.5062 - categorical_accuracy: 0.96 - ETA: 4s - loss: 0.5060 - categorical_accuracy: 0.96 - ETA: 3s - loss: 0.5059 - categorical_accuracy: 0.96 - ETA: 2s - loss: 0.5056 - categorical_accuracy: 0.96 - ETA: 2s - loss: 0.5055 - categorical_accuracy: 0.96 - ETA: 1s - loss: 0.5053 - categorical_accuracy: 0.96 - ETA: 0s - loss: 0.5052 - categorical_accuracy: 0.96 - 40s 242ms/step - loss: 0.5051 - categorical_accuracy: 0.9694
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 5s 115ms/step
# Jacard Index : 0.049153889988735475
# Dice Coefficient : 0.09359323504255955
# ***********************************************
# Jacard Index improved from 0.04107588443071215 to 0.049153889988735475
# ***********************************************
# Epoch : 4
# Epoch 1/1
# 165/165 [==============================] - ETA: 37s - loss: 0.5011 - categorical_accuracy: 0.966 - ETA: 1:51 - loss: 0.4953 - categorical_accuracy: 0.97 - ETA: 1:34 - loss: 0.4936 - categorical_accuracy: 0.97 - ETA: 1:18 - loss: 0.4932 - categorical_accuracy: 0.97 - ETA: 1:07 - loss: 0.4929 - categorical_accuracy: 0.97 - ETA: 1:00 - loss: 0.4928 - categorical_accuracy: 0.97 - ETA: 54s - loss: 0.4928 - categorical_accuracy: 0.9738 - ETA: 48s - loss: 0.4918 - categorical_accuracy: 0.974 - ETA: 44s - loss: 0.4923 - categorical_accuracy: 0.973 - ETA: 41s - loss: 0.4918 - categorical_accuracy: 0.974 - ETA: 39s - loss: 0.4913 - categorical_accuracy: 0.974 - ETA: 39s - loss: 0.4911 - categorical_accuracy: 0.974 - ETA: 43s - loss: 0.4913 - categorical_accuracy: 0.974 - ETA: 43s - loss: 0.4915 - categorical_accuracy: 0.973 - ETA: 40s - loss: 0.4912 - categorical_accuracy: 0.973 - ETA: 38s - loss: 0.4914 - categorical_accuracy: 0.973 - ETA: 36s - loss: 0.4910 - categorical_accuracy: 0.974 - ETA: 34s - loss: 0.4907 - categorical_accuracy: 0.973 - ETA: 32s - loss: 0.4903 - categorical_accuracy: 0.974 - ETA: 30s - loss: 0.4902 - categorical_accuracy: 0.974 - ETA: 28s - loss: 0.4898 - categorical_accuracy: 0.974 - ETA: 27s - loss: 0.4895 - categorical_accuracy: 0.974 - ETA: 29s - loss: 0.4898 - categorical_accuracy: 0.974 - ETA: 28s - loss: 0.4896 - categorical_accuracy: 0.973 - ETA: 28s - loss: 0.4892 - categorical_accuracy: 0.974 - ETA: 26s - loss: 0.4891 - categorical_accuracy: 0.974 - ETA: 25s - loss: 0.4888 - categorical_accuracy: 0.974 - ETA: 24s - loss: 0.4889 - categorical_accuracy: 0.974 - ETA: 22s - loss: 0.4885 - categorical_accuracy: 0.974 - ETA: 21s - loss: 0.4885 - categorical_accuracy: 0.974 - ETA: 20s - loss: 0.4881 - categorical_accuracy: 0.974 - ETA: 19s - loss: 0.4882 - categorical_accuracy: 0.974 - ETA: 18s - loss: 0.4878 - categorical_accuracy: 0.974 - ETA: 16s - loss: 0.4876 - categorical_accuracy: 0.974 - ETA: 15s - loss: 0.4875 - categorical_accuracy: 0.973 - ETA: 14s - loss: 0.4873 - categorical_accuracy: 0.974 - ETA: 13s - loss: 0.4871 - categorical_accuracy: 0.974 - ETA: 12s - loss: 0.4868 - categorical_accuracy: 0.974 - ETA: 12s - loss: 0.4866 - categorical_accuracy: 0.974 - ETA: 11s - loss: 0.4864 - categorical_accuracy: 0.973 - ETA: 10s - loss: 0.4862 - categorical_accuracy: 0.973 - ETA: 9s - loss: 0.4860 - categorical_accuracy: 0.973 - ETA: 8s - loss: 0.4858 - categorical_accuracy: 0.97 - ETA: 7s - loss: 0.4857 - categorical_accuracy: 0.97 - ETA: 7s - loss: 0.4854 - categorical_accuracy: 0.97 - ETA: 6s - loss: 0.4852 - categorical_accuracy: 0.97 - ETA: 5s - loss: 0.4850 - categorical_accuracy: 0.97 - ETA: 4s - loss: 0.4847 - categorical_accuracy: 0.97 - ETA: 4s - loss: 0.4845 - categorical_accuracy: 0.97 - ETA: 3s - loss: 0.4842 - categorical_accuracy: 0.97 - ETA: 2s - loss: 0.4840 - categorical_accuracy: 0.97 - ETA: 2s - loss: 0.4838 - categorical_accuracy: 0.97 - ETA: 1s - loss: 0.4838 - categorical_accuracy: 0.97 - ETA: 0s - loss: 0.4837 - categorical_accuracy: 0.97 - 37s 222ms/step - loss: 0.4837 - categorical_accuracy: 0.9737
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 48ms/step
# Jacard Index : 0.10909909481116968
# Dice Coefficient : 0.19648349731330308
# ***********************************************
# Jacard Index improved from 0.049153889988735475 to 0.10909909481116968
# ***********************************************
# Epoch : 5
# Epoch 1/1
# 165/165 [==============================] - ETA: 38s - loss: 0.4765 - categorical_accuracy: 0.976 - ETA: 30s - loss: 0.4776 - categorical_accuracy: 0.977 - ETA: 26s - loss: 0.4756 - categorical_accuracy: 0.979 - ETA: 25s - loss: 0.4751 - categorical_accuracy: 0.978 - ETA: 25s - loss: 0.4744 - categorical_accuracy: 0.978 - ETA: 24s - loss: 0.4746 - categorical_accuracy: 0.977 - ETA: 24s - loss: 0.4742 - categorical_accuracy: 0.977 - ETA: 22s - loss: 0.4743 - categorical_accuracy: 0.976 - ETA: 23s - loss: 0.4741 - categorical_accuracy: 0.976 - ETA: 22s - loss: 0.4739 - categorical_accuracy: 0.976 - ETA: 22s - loss: 0.4735 - categorical_accuracy: 0.976 - ETA: 21s - loss: 0.4733 - categorical_accuracy: 0.976 - ETA: 21s - loss: 0.4734 - categorical_accuracy: 0.975 - ETA: 20s - loss: 0.4728 - categorical_accuracy: 0.975 - ETA: 19s - loss: 0.4725 - categorical_accuracy: 0.975 - ETA: 19s - loss: 0.4722 - categorical_accuracy: 0.976 - ETA: 18s - loss: 0.4720 - categorical_accuracy: 0.975 - ETA: 17s - loss: 0.4718 - categorical_accuracy: 0.975 - ETA: 17s - loss: 0.4716 - categorical_accuracy: 0.975 - ETA: 16s - loss: 0.4715 - categorical_accuracy: 0.975 - ETA: 16s - loss: 0.4712 - categorical_accuracy: 0.975 - ETA: 15s - loss: 0.4710 - categorical_accuracy: 0.975 - ETA: 15s - loss: 0.4708 - categorical_accuracy: 0.975 - ETA: 14s - loss: 0.4706 - categorical_accuracy: 0.975 - ETA: 14s - loss: 0.4704 - categorical_accuracy: 0.975 - ETA: 13s - loss: 0.4704 - categorical_accuracy: 0.975 - ETA: 13s - loss: 0.4701 - categorical_accuracy: 0.975 - ETA: 12s - loss: 0.4699 - categorical_accuracy: 0.975 - ETA: 12s - loss: 0.4695 - categorical_accuracy: 0.975 - ETA: 11s - loss: 0.4694 - categorical_accuracy: 0.975 - ETA: 11s - loss: 0.4692 - categorical_accuracy: 0.975 - ETA: 11s - loss: 0.4692 - categorical_accuracy: 0.975 - ETA: 10s - loss: 0.4690 - categorical_accuracy: 0.975 - ETA: 10s - loss: 0.4687 - categorical_accuracy: 0.975 - ETA: 9s - loss: 0.4685 - categorical_accuracy: 0.975 - ETA: 9s - loss: 0.4684 - categorical_accuracy: 0.97 - ETA: 9s - loss: 0.4683 - categorical_accuracy: 0.97 - ETA: 8s - loss: 0.4682 - categorical_accuracy: 0.97 - ETA: 8s - loss: 0.4680 - categorical_accuracy: 0.97 - ETA: 7s - loss: 0.4678 - categorical_accuracy: 0.97 - ETA: 6s - loss: 0.4676 - categorical_accuracy: 0.97 - ETA: 6s - loss: 0.4674 - categorical_accuracy: 0.97 - ETA: 5s - loss: 0.4673 - categorical_accuracy: 0.97 - ETA: 5s - loss: 0.4673 - categorical_accuracy: 0.97 - ETA: 4s - loss: 0.4672 - categorical_accuracy: 0.97 - ETA: 4s - loss: 0.4670 - categorical_accuracy: 0.97 - ETA: 3s - loss: 0.4669 - categorical_accuracy: 0.97 - ETA: 3s - loss: 0.4668 - categorical_accuracy: 0.97 - ETA: 2s - loss: 0.4665 - categorical_accuracy: 0.97 - ETA: 2s - loss: 0.4663 - categorical_accuracy: 0.97 - ETA: 1s - loss: 0.4662 - categorical_accuracy: 0.97 - ETA: 1s - loss: 0.4661 - categorical_accuracy: 0.97 - ETA: 0s - loss: 0.4661 - categorical_accuracy: 0.97 - ETA: 0s - loss: 0.4659 - categorical_accuracy: 0.97 - 27s 165ms/step - loss: 0.4658 - categorical_accuracy: 0.9749
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 57ms/step
# Jacard Index : 0.24253801559504154
# Dice Coefficient : 0.3900947194339932
# ***********************************************
# Jacard Index improved from 0.10909909481116968 to 0.24253801559504154
# ***********************************************
# Epoch : 6
# Epoch 1/1
# 165/165 [==============================] - ETA: 1:00 - loss: 0.4563 - categorical_accuracy: 0.97 - ETA: 54s - loss: 0.4549 - categorical_accuracy: 0.9776 - ETA: 48s - loss: 0.4544 - categorical_accuracy: 0.978 - ETA: 41s - loss: 0.4543 - categorical_accuracy: 0.978 - ETA: 38s - loss: 0.4539 - categorical_accuracy: 0.978 - ETA: 39s - loss: 0.4532 - categorical_accuracy: 0.979 - ETA: 37s - loss: 0.4534 - categorical_accuracy: 0.978 - ETA: 35s - loss: 0.4527 - categorical_accuracy: 0.978 - ETA: 46s - loss: 0.4532 - categorical_accuracy: 0.977 - ETA: 45s - loss: 0.4535 - categorical_accuracy: 0.976 - ETA: 42s - loss: 0.4536 - categorical_accuracy: 0.976 - ETA: 46s - loss: 0.4535 - categorical_accuracy: 0.976 - ETA: 43s - loss: 0.4532 - categorical_accuracy: 0.976 - ETA: 40s - loss: 0.4534 - categorical_accuracy: 0.976 - ETA: 40s - loss: 0.4532 - categorical_accuracy: 0.976 - ETA: 38s - loss: 0.4528 - categorical_accuracy: 0.976 - ETA: 37s - loss: 0.4526 - categorical_accuracy: 0.977 - ETA: 35s - loss: 0.4526 - categorical_accuracy: 0.977 - ETA: 34s - loss: 0.4522 - categorical_accuracy: 0.977 - ETA: 34s - loss: 0.4524 - categorical_accuracy: 0.976 - ETA: 32s - loss: 0.4523 - categorical_accuracy: 0.976 - ETA: 31s - loss: 0.4521 - categorical_accuracy: 0.976 - ETA: 29s - loss: 0.4519 - categorical_accuracy: 0.976 - ETA: 28s - loss: 0.4517 - categorical_accuracy: 0.976 - ETA: 26s - loss: 0.4516 - categorical_accuracy: 0.976 - ETA: 25s - loss: 0.4515 - categorical_accuracy: 0.976 - ETA: 24s - loss: 0.4515 - categorical_accuracy: 0.976 - ETA: 23s - loss: 0.4513 - categorical_accuracy: 0.976 - ETA: 22s - loss: 0.4514 - categorical_accuracy: 0.976 - ETA: 21s - loss: 0.4514 - categorical_accuracy: 0.976 - ETA: 20s - loss: 0.4512 - categorical_accuracy: 0.976 - ETA: 19s - loss: 0.4510 - categorical_accuracy: 0.976 - ETA: 18s - loss: 0.4508 - categorical_accuracy: 0.977 - ETA: 17s - loss: 0.4506 - categorical_accuracy: 0.977 - ETA: 16s - loss: 0.4506 - categorical_accuracy: 0.976 - ETA: 15s - loss: 0.4505 - categorical_accuracy: 0.976 - ETA: 14s - loss: 0.4504 - categorical_accuracy: 0.976 - ETA: 13s - loss: 0.4504 - categorical_accuracy: 0.976 - ETA: 12s - loss: 0.4503 - categorical_accuracy: 0.976 - ETA: 11s - loss: 0.4501 - categorical_accuracy: 0.976 - ETA: 10s - loss: 0.4501 - categorical_accuracy: 0.975 - ETA: 9s - loss: 0.4499 - categorical_accuracy: 0.975 - ETA: 9s - loss: 0.4497 - categorical_accuracy: 0.97 - ETA: 8s - loss: 0.4495 - categorical_accuracy: 0.97 - ETA: 7s - loss: 0.4494 - categorical_accuracy: 0.97 - ETA: 6s - loss: 0.4492 - categorical_accuracy: 0.97 - ETA: 6s - loss: 0.4493 - categorical_accuracy: 0.97 - ETA: 5s - loss: 0.4491 - categorical_accuracy: 0.97 - ETA: 4s - loss: 0.4490 - categorical_accuracy: 0.97 - ETA: 3s - loss: 0.4489 - categorical_accuracy: 0.97 - ETA: 2s - loss: 0.4487 - categorical_accuracy: 0.97 - ETA: 2s - loss: 0.4486 - categorical_accuracy: 0.97 - ETA: 1s - loss: 0.4485 - categorical_accuracy: 0.97 - ETA: 0s - loss: 0.4483 - categorical_accuracy: 0.97 - 40s 241ms/step - loss: 0.4482 - categorical_accuracy: 0.9758
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 58ms/step
# Jacard Index : 0.09614806534401865
# Dice Coefficient : 0.17521625433242352
# Epoch : 7
# Epoch 1/1
# 165/165 [==============================] - ETA: 33s - loss: 0.4351 - categorical_accuracy: 0.972 - ETA: 36s - loss: 0.4352 - categorical_accuracy: 0.973 - ETA: 36s - loss: 0.4355 - categorical_accuracy: 0.973 - ETA: 31s - loss: 0.4364 - categorical_accuracy: 0.972 - ETA: 28s - loss: 0.4374 - categorical_accuracy: 0.971 - ETA: 26s - loss: 0.4372 - categorical_accuracy: 0.972 - ETA: 24s - loss: 0.4378 - categorical_accuracy: 0.972 - ETA: 24s - loss: 0.4380 - categorical_accuracy: 0.973 - ETA: 22s - loss: 0.4379 - categorical_accuracy: 0.973 - ETA: 21s - loss: 0.4378 - categorical_accuracy: 0.974 - ETA: 21s - loss: 0.4381 - categorical_accuracy: 0.974 - ETA: 22s - loss: 0.4377 - categorical_accuracy: 0.974 - ETA: 22s - loss: 0.4377 - categorical_accuracy: 0.974 - ETA: 21s - loss: 0.4378 - categorical_accuracy: 0.974 - ETA: 20s - loss: 0.4374 - categorical_accuracy: 0.974 - ETA: 19s - loss: 0.4373 - categorical_accuracy: 0.975 - ETA: 19s - loss: 0.4371 - categorical_accuracy: 0.975 - ETA: 18s - loss: 0.4373 - categorical_accuracy: 0.975 - ETA: 17s - loss: 0.4371 - categorical_accuracy: 0.975 - ETA: 17s - loss: 0.4370 - categorical_accuracy: 0.975 - ETA: 16s - loss: 0.4368 - categorical_accuracy: 0.975 - ETA: 16s - loss: 0.4365 - categorical_accuracy: 0.975 - ETA: 15s - loss: 0.4362 - categorical_accuracy: 0.976 - ETA: 15s - loss: 0.4359 - categorical_accuracy: 0.976 - ETA: 14s - loss: 0.4358 - categorical_accuracy: 0.976 - ETA: 14s - loss: 0.4357 - categorical_accuracy: 0.976 - ETA: 13s - loss: 0.4355 - categorical_accuracy: 0.976 - ETA: 13s - loss: 0.4354 - categorical_accuracy: 0.976 - ETA: 12s - loss: 0.4353 - categorical_accuracy: 0.976 - ETA: 12s - loss: 0.4349 - categorical_accuracy: 0.976 - ETA: 11s - loss: 0.4348 - categorical_accuracy: 0.976 - ETA: 11s - loss: 0.4346 - categorical_accuracy: 0.976 - ETA: 10s - loss: 0.4346 - categorical_accuracy: 0.976 - ETA: 10s - loss: 0.4345 - categorical_accuracy: 0.976 - ETA: 9s - loss: 0.4343 - categorical_accuracy: 0.976 - ETA: 9s - loss: 0.4341 - categorical_accuracy: 0.97 - ETA: 8s - loss: 0.4341 - categorical_accuracy: 0.97 - ETA: 8s - loss: 0.4339 - categorical_accuracy: 0.97 - ETA: 7s - loss: 0.4337 - categorical_accuracy: 0.97 - ETA: 7s - loss: 0.4335 - categorical_accuracy: 0.97 - ETA: 6s - loss: 0.4334 - categorical_accuracy: 0.97 - ETA: 6s - loss: 0.4332 - categorical_accuracy: 0.97 - ETA: 5s - loss: 0.4329 - categorical_accuracy: 0.97 - ETA: 5s - loss: 0.4327 - categorical_accuracy: 0.97 - ETA: 4s - loss: 0.4324 - categorical_accuracy: 0.97 - ETA: 4s - loss: 0.4323 - categorical_accuracy: 0.97 - ETA: 3s - loss: 0.4321 - categorical_accuracy: 0.97 - ETA: 3s - loss: 0.4319 - categorical_accuracy: 0.97 - ETA: 2s - loss: 0.4316 - categorical_accuracy: 0.97 - ETA: 2s - loss: 0.4314 - categorical_accuracy: 0.97 - ETA: 1s - loss: 0.4313 - categorical_accuracy: 0.97 - ETA: 1s - loss: 0.4312 - categorical_accuracy: 0.97 - ETA: 0s - loss: 0.4312 - categorical_accuracy: 0.97 - ETA: 0s - loss: 0.4310 - categorical_accuracy: 0.97 - 25s 153ms/step - loss: 0.4309 - categorical_accuracy: 0.9772
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 54ms/step
# Jacard Index : 0.6321029302037303
# Dice Coefficient : 0.774430471062863
# ***********************************************
# Jacard Index improved from 0.24253801559504154 to 0.6321029302037303
# ***********************************************
# Epoch : 8
# Epoch 1/1
# 165/165 [==============================] - ETA: 31s - loss: 0.4199 - categorical_accuracy: 0.982 - ETA: 26s - loss: 0.4238 - categorical_accuracy: 0.978 - ETA: 27s - loss: 0.4231 - categorical_accuracy: 0.978 - ETA: 29s - loss: 0.4228 - categorical_accuracy: 0.979 - ETA: 27s - loss: 0.4222 - categorical_accuracy: 0.979 - ETA: 26s - loss: 0.4216 - categorical_accuracy: 0.980 - ETA: 25s - loss: 0.4223 - categorical_accuracy: 0.980 - ETA: 24s - loss: 0.4224 - categorical_accuracy: 0.980 - ETA: 24s - loss: 0.4218 - categorical_accuracy: 0.980 - ETA: 23s - loss: 0.4214 - categorical_accuracy: 0.979 - ETA: 23s - loss: 0.4212 - categorical_accuracy: 0.979 - ETA: 22s - loss: 0.4211 - categorical_accuracy: 0.979 - ETA: 25s - loss: 0.4207 - categorical_accuracy: 0.979 - ETA: 24s - loss: 0.4208 - categorical_accuracy: 0.979 - ETA: 26s - loss: 0.4207 - categorical_accuracy: 0.979 - ETA: 25s - loss: 0.4203 - categorical_accuracy: 0.979 - ETA: 24s - loss: 0.4203 - categorical_accuracy: 0.979 - ETA: 23s - loss: 0.4201 - categorical_accuracy: 0.979 - ETA: 22s - loss: 0.4198 - categorical_accuracy: 0.979 - ETA: 22s - loss: 0.4195 - categorical_accuracy: 0.979 - ETA: 21s - loss: 0.4192 - categorical_accuracy: 0.979 - ETA: 20s - loss: 0.4193 - categorical_accuracy: 0.979 - ETA: 19s - loss: 0.4190 - categorical_accuracy: 0.979 - ETA: 18s - loss: 0.4188 - categorical_accuracy: 0.979 - ETA: 17s - loss: 0.4186 - categorical_accuracy: 0.979 - ETA: 17s - loss: 0.4186 - categorical_accuracy: 0.979 - ETA: 16s - loss: 0.4184 - categorical_accuracy: 0.979 - ETA: 16s - loss: 0.4185 - categorical_accuracy: 0.979 - ETA: 15s - loss: 0.4185 - categorical_accuracy: 0.979 - ETA: 15s - loss: 0.4182 - categorical_accuracy: 0.979 - ETA: 14s - loss: 0.4180 - categorical_accuracy: 0.979 - ETA: 13s - loss: 0.4179 - categorical_accuracy: 0.979 - ETA: 13s - loss: 0.4177 - categorical_accuracy: 0.979 - ETA: 12s - loss: 0.4175 - categorical_accuracy: 0.979 - ETA: 11s - loss: 0.4173 - categorical_accuracy: 0.979 - ETA: 11s - loss: 0.4173 - categorical_accuracy: 0.979 - ETA: 10s - loss: 0.4171 - categorical_accuracy: 0.979 - ETA: 9s - loss: 0.4168 - categorical_accuracy: 0.979 - ETA: 9s - loss: 0.4166 - categorical_accuracy: 0.97 - ETA: 8s - loss: 0.4165 - categorical_accuracy: 0.97 - ETA: 8s - loss: 0.4164 - categorical_accuracy: 0.97 - ETA: 7s - loss: 0.4163 - categorical_accuracy: 0.97 - ETA: 6s - loss: 0.4162 - categorical_accuracy: 0.97 - ETA: 6s - loss: 0.4162 - categorical_accuracy: 0.97 - ETA: 5s - loss: 0.4160 - categorical_accuracy: 0.97 - ETA: 5s - loss: 0.4159 - categorical_accuracy: 0.97 - ETA: 4s - loss: 0.4158 - categorical_accuracy: 0.97 - ETA: 4s - loss: 0.4156 - categorical_accuracy: 0.97 - ETA: 3s - loss: 0.4154 - categorical_accuracy: 0.97 - ETA: 2s - loss: 0.4152 - categorical_accuracy: 0.97 - ETA: 2s - loss: 0.4150 - categorical_accuracy: 0.97 - ETA: 1s - loss: 0.4149 - categorical_accuracy: 0.97 - ETA: 1s - loss: 0.4148 - categorical_accuracy: 0.97 - ETA: 0s - loss: 0.4146 - categorical_accuracy: 0.97 - 32s 191ms/step - loss: 0.4143 - categorical_accuracy: 0.9797
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 60ms/step
# Jacard Index : 0.5975548933974489
# Dice Coefficient : 0.747835475344556
# Epoch : 9
# Epoch 1/1
# 165/165 [==============================] - ETA: 28s - loss: 0.4022 - categorical_accuracy: 0.982 - ETA: 30s - loss: 0.4057 - categorical_accuracy: 0.980 - ETA: 26s - loss: 0.4054 - categorical_accuracy: 0.980 - ETA: 25s - loss: 0.4057 - categorical_accuracy: 0.980 - ETA: 24s - loss: 0.4059 - categorical_accuracy: 0.980 - ETA: 23s - loss: 0.4064 - categorical_accuracy: 0.980 - ETA: 22s - loss: 0.4060 - categorical_accuracy: 0.980 - ETA: 24s - loss: 0.4055 - categorical_accuracy: 0.981 - ETA: 25s - loss: 0.4057 - categorical_accuracy: 0.981 - ETA: 25s - loss: 0.4053 - categorical_accuracy: 0.981 - ETA: 32s - loss: 0.4053 - categorical_accuracy: 0.981 - ETA: 30s - loss: 0.4056 - categorical_accuracy: 0.981 - ETA: 28s - loss: 0.4054 - categorical_accuracy: 0.981 - ETA: 27s - loss: 0.4048 - categorical_accuracy: 0.981 - ETA: 26s - loss: 0.4044 - categorical_accuracy: 0.981 - ETA: 24s - loss: 0.4047 - categorical_accuracy: 0.981 - ETA: 23s - loss: 0.4044 - categorical_accuracy: 0.981 - ETA: 22s - loss: 0.4040 - categorical_accuracy: 0.981 - ETA: 21s - loss: 0.4041 - categorical_accuracy: 0.981 - ETA: 21s - loss: 0.4038 - categorical_accuracy: 0.981 - ETA: 20s - loss: 0.4034 - categorical_accuracy: 0.981 - ETA: 20s - loss: 0.4032 - categorical_accuracy: 0.981 - ETA: 19s - loss: 0.4030 - categorical_accuracy: 0.981 - ETA: 18s - loss: 0.4030 - categorical_accuracy: 0.981 - ETA: 18s - loss: 0.4030 - categorical_accuracy: 0.981 - ETA: 18s - loss: 0.4027 - categorical_accuracy: 0.981 - ETA: 17s - loss: 0.4025 - categorical_accuracy: 0.981 - ETA: 16s - loss: 0.4023 - categorical_accuracy: 0.981 - ETA: 16s - loss: 0.4022 - categorical_accuracy: 0.981 - ETA: 15s - loss: 0.4020 - categorical_accuracy: 0.981 - ETA: 15s - loss: 0.4019 - categorical_accuracy: 0.981 - ETA: 14s - loss: 0.4018 - categorical_accuracy: 0.981 - ETA: 13s - loss: 0.4016 - categorical_accuracy: 0.981 - ETA: 13s - loss: 0.4015 - categorical_accuracy: 0.981 - ETA: 12s - loss: 0.4013 - categorical_accuracy: 0.981 - ETA: 12s - loss: 0.4011 - categorical_accuracy: 0.981 - ETA: 11s - loss: 0.4009 - categorical_accuracy: 0.981 - ETA: 10s - loss: 0.4007 - categorical_accuracy: 0.981 - ETA: 9s - loss: 0.4006 - categorical_accuracy: 0.981 - ETA: 9s - loss: 0.4003 - categorical_accuracy: 0.98 - ETA: 8s - loss: 0.4003 - categorical_accuracy: 0.98 - ETA: 8s - loss: 0.4003 - categorical_accuracy: 0.98 - ETA: 7s - loss: 0.4002 - categorical_accuracy: 0.98 - ETA: 7s - loss: 0.4001 - categorical_accuracy: 0.98 - ETA: 7s - loss: 0.4000 - categorical_accuracy: 0.98 - ETA: 6s - loss: 0.4000 - categorical_accuracy: 0.98 - ETA: 5s - loss: 0.3999 - categorical_accuracy: 0.98 - ETA: 4s - loss: 0.3997 - categorical_accuracy: 0.98 - ETA: 4s - loss: 0.3995 - categorical_accuracy: 0.98 - ETA: 3s - loss: 0.3995 - categorical_accuracy: 0.98 - ETA: 2s - loss: 0.3994 - categorical_accuracy: 0.98 - ETA: 2s - loss: 0.3993 - categorical_accuracy: 0.98 - ETA: 1s - loss: 0.3991 - categorical_accuracy: 0.98 - ETA: 0s - loss: 0.3990 - categorical_accuracy: 0.98 - 36s 220ms/step - loss: 0.3989 - categorical_accuracy: 0.9813
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 49ms/step
# Jacard Index : 0.7264785988608493
# Dice Coefficient : 0.8409384470955565
# ***********************************************
# Jacard Index improved from 0.6321029302037303 to 0.7264785988608493
# ***********************************************
# Epoch : 10
# Epoch 1/1
# 165/165 [==============================] - ETA: 45s - loss: 0.3951 - categorical_accuracy: 0.980 - ETA: 38s - loss: 0.3913 - categorical_accuracy: 0.982 - ETA: 37s - loss: 0.3904 - categorical_accuracy: 0.983 - ETA: 32s - loss: 0.3908 - categorical_accuracy: 0.982 - ETA: 30s - loss: 0.3910 - categorical_accuracy: 0.981 - ETA: 28s - loss: 0.3913 - categorical_accuracy: 0.980 - ETA: 26s - loss: 0.3912 - categorical_accuracy: 0.980 - ETA: 25s - loss: 0.3910 - categorical_accuracy: 0.980 - ETA: 28s - loss: 0.3911 - categorical_accuracy: 0.980 - ETA: 27s - loss: 0.3909 - categorical_accuracy: 0.980 - ETA: 25s - loss: 0.3907 - categorical_accuracy: 0.981 - ETA: 25s - loss: 0.3904 - categorical_accuracy: 0.981 - ETA: 24s - loss: 0.3898 - categorical_accuracy: 0.981 - ETA: 23s - loss: 0.3895 - categorical_accuracy: 0.981 - ETA: 23s - loss: 0.3896 - categorical_accuracy: 0.980 - ETA: 22s - loss: 0.3894 - categorical_accuracy: 0.980 - ETA: 21s - loss: 0.3897 - categorical_accuracy: 0.980 - ETA: 21s - loss: 0.3897 - categorical_accuracy: 0.980 - ETA: 21s - loss: 0.3896 - categorical_accuracy: 0.980 - ETA: 22s - loss: 0.3895 - categorical_accuracy: 0.980 - ETA: 21s - loss: 0.3895 - categorical_accuracy: 0.980 - ETA: 20s - loss: 0.3897 - categorical_accuracy: 0.980 - ETA: 19s - loss: 0.3895 - categorical_accuracy: 0.980 - ETA: 18s - loss: 0.3894 - categorical_accuracy: 0.980 - ETA: 17s - loss: 0.3892 - categorical_accuracy: 0.980 - ETA: 17s - loss: 0.3893 - categorical_accuracy: 0.980 - ETA: 16s - loss: 0.3893 - categorical_accuracy: 0.980 - ETA: 15s - loss: 0.3892 - categorical_accuracy: 0.980 - ETA: 15s - loss: 0.3890 - categorical_accuracy: 0.980 - ETA: 14s - loss: 0.3888 - categorical_accuracy: 0.980 - ETA: 14s - loss: 0.3887 - categorical_accuracy: 0.980 - ETA: 13s - loss: 0.3886 - categorical_accuracy: 0.980 - ETA: 13s - loss: 0.3885 - categorical_accuracy: 0.980 - ETA: 12s - loss: 0.3883 - categorical_accuracy: 0.980 - ETA: 12s - loss: 0.3881 - categorical_accuracy: 0.980 - ETA: 11s - loss: 0.3879 - categorical_accuracy: 0.980 - ETA: 11s - loss: 0.3877 - categorical_accuracy: 0.980 - ETA: 10s - loss: 0.3875 - categorical_accuracy: 0.980 - ETA: 9s - loss: 0.3873 - categorical_accuracy: 0.980 - ETA: 9s - loss: 0.3871 - categorical_accuracy: 0.98 - ETA: 8s - loss: 0.3870 - categorical_accuracy: 0.98 - ETA: 7s - loss: 0.3868 - categorical_accuracy: 0.98 - ETA: 7s - loss: 0.3866 - categorical_accuracy: 0.98 - ETA: 6s - loss: 0.3867 - categorical_accuracy: 0.98 - ETA: 5s - loss: 0.3866 - categorical_accuracy: 0.98 - ETA: 5s - loss: 0.3864 - categorical_accuracy: 0.98 - ETA: 4s - loss: 0.3862 - categorical_accuracy: 0.98 - ETA: 4s - loss: 0.3860 - categorical_accuracy: 0.98 - ETA: 3s - loss: 0.3859 - categorical_accuracy: 0.98 - ETA: 2s - loss: 0.3857 - categorical_accuracy: 0.98 - ETA: 2s - loss: 0.3856 - categorical_accuracy: 0.98 - ETA: 1s - loss: 0.3855 - categorical_accuracy: 0.98 - ETA: 1s - loss: 0.3853 - categorical_accuracy: 0.98 - ETA: 0s - loss: 0.3853 - categorical_accuracy: 0.98 - 31s 189ms/step - loss: 0.3851 - categorical_accuracy: 0.9810
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 47ms/step
# Jacard Index : 0.9283025297604285
# Dice Coefficient : 0.9626005439271014
# ***********************************************
# Jacard Index improved from 0.7264785988608493 to 0.9283025297604285
# ***********************************************
# Epoch : 11
# Epoch 1/1
# 165/165 [==============================] - ETA: 38s - loss: 0.3752 - categorical_accuracy: 0.985 - ETA: 40s - loss: 0.3760 - categorical_accuracy: 0.983 - ETA: 34s - loss: 0.3774 - categorical_accuracy: 0.982 - ETA: 30s - loss: 0.3764 - categorical_accuracy: 0.982 - ETA: 28s - loss: 0.3756 - categorical_accuracy: 0.983 - ETA: 26s - loss: 0.3757 - categorical_accuracy: 0.983 - ETA: 25s - loss: 0.3758 - categorical_accuracy: 0.983 - ETA: 24s - loss: 0.3751 - categorical_accuracy: 0.983 - ETA: 23s - loss: 0.3750 - categorical_accuracy: 0.983 - ETA: 22s - loss: 0.3749 - categorical_accuracy: 0.983 - ETA: 22s - loss: 0.3748 - categorical_accuracy: 0.982 - ETA: 21s - loss: 0.3751 - categorical_accuracy: 0.982 - ETA: 20s - loss: 0.3751 - categorical_accuracy: 0.982 - ETA: 20s - loss: 0.3752 - categorical_accuracy: 0.982 - ETA: 19s - loss: 0.3751 - categorical_accuracy: 0.982 - ETA: 18s - loss: 0.3749 - categorical_accuracy: 0.982 - ETA: 18s - loss: 0.3750 - categorical_accuracy: 0.982 - ETA: 17s - loss: 0.3748 - categorical_accuracy: 0.982 - ETA: 17s - loss: 0.3748 - categorical_accuracy: 0.982 - ETA: 16s - loss: 0.3749 - categorical_accuracy: 0.982 - ETA: 15s - loss: 0.3749 - categorical_accuracy: 0.982 - ETA: 15s - loss: 0.3749 - categorical_accuracy: 0.982 - ETA: 14s - loss: 0.3748 - categorical_accuracy: 0.982 - ETA: 14s - loss: 0.3747 - categorical_accuracy: 0.982 - ETA: 13s - loss: 0.3747 - categorical_accuracy: 0.982 - ETA: 13s - loss: 0.3746 - categorical_accuracy: 0.982 - ETA: 12s - loss: 0.3744 - categorical_accuracy: 0.982 - ETA: 12s - loss: 0.3743 - categorical_accuracy: 0.982 - ETA: 11s - loss: 0.3743 - categorical_accuracy: 0.982 - ETA: 11s - loss: 0.3741 - categorical_accuracy: 0.982 - ETA: 10s - loss: 0.3740 - categorical_accuracy: 0.982 - ETA: 11s - loss: 0.3740 - categorical_accuracy: 0.982 - ETA: 11s - loss: 0.3738 - categorical_accuracy: 0.982 - ETA: 11s - loss: 0.3738 - categorical_accuracy: 0.982 - ETA: 10s - loss: 0.3738 - categorical_accuracy: 0.982 - ETA: 9s - loss: 0.3736 - categorical_accuracy: 0.982 - ETA: 9s - loss: 0.3734 - categorical_accuracy: 0.98 - ETA: 9s - loss: 0.3733 - categorical_accuracy: 0.98 - ETA: 8s - loss: 0.3731 - categorical_accuracy: 0.98 - ETA: 8s - loss: 0.3730 - categorical_accuracy: 0.98 - ETA: 7s - loss: 0.3729 - categorical_accuracy: 0.98 - ETA: 7s - loss: 0.3727 - categorical_accuracy: 0.98 - ETA: 6s - loss: 0.3726 - categorical_accuracy: 0.98 - ETA: 6s - loss: 0.3725 - categorical_accuracy: 0.98 - ETA: 5s - loss: 0.3724 - categorical_accuracy: 0.98 - ETA: 5s - loss: 0.3722 - categorical_accuracy: 0.98 - ETA: 4s - loss: 0.3721 - categorical_accuracy: 0.98 - ETA: 3s - loss: 0.3719 - categorical_accuracy: 0.98 - ETA: 3s - loss: 0.3718 - categorical_accuracy: 0.98 - ETA: 2s - loss: 0.3717 - categorical_accuracy: 0.98 - ETA: 2s - loss: 0.3716 - categorical_accuracy: 0.98 - ETA: 1s - loss: 0.3716 - categorical_accuracy: 0.98 - ETA: 1s - loss: 0.3714 - categorical_accuracy: 0.98 - ETA: 0s - loss: 0.3713 - categorical_accuracy: 0.98 - 31s 185ms/step - loss: 0.3712 - categorical_accuracy: 0.9821
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 45ms/step
# Jacard Index : 0.9345857082082455
# Dice Coefficient : 0.9660991422367095
# ***********************************************
# Jacard Index improved from 0.9283025297604285 to 0.9345857082082455
# ***********************************************
# Epoch : 12
# Epoch 1/1
# 165/165 [==============================] - ETA: 1:18 - loss: 0.3624 - categorical_accuracy: 0.98 - ETA: 1:08 - loss: 0.3638 - categorical_accuracy: 0.98 - ETA: 1:03 - loss: 0.3630 - categorical_accuracy: 0.98 - ETA: 58s - loss: 0.3637 - categorical_accuracy: 0.9816 - ETA: 53s - loss: 0.3644 - categorical_accuracy: 0.981 - ETA: 1:08 - loss: 0.3640 - categorical_accuracy: 0.98 - ETA: 1:00 - loss: 0.3639 - categorical_accuracy: 0.98 - ETA: 59s - loss: 0.3638 - categorical_accuracy: 0.9819 - ETA: 53s - loss: 0.3641 - categorical_accuracy: 0.981 - ETA: 50s - loss: 0.3638 - categorical_accuracy: 0.981 - ETA: 48s - loss: 0.3635 - categorical_accuracy: 0.982 - ETA: 44s - loss: 0.3635 - categorical_accuracy: 0.982 - ETA: 41s - loss: 0.3633 - categorical_accuracy: 0.982 - ETA: 39s - loss: 0.3633 - categorical_accuracy: 0.982 - ETA: 36s - loss: 0.3631 - categorical_accuracy: 0.982 - ETA: 34s - loss: 0.3633 - categorical_accuracy: 0.982 - ETA: 33s - loss: 0.3630 - categorical_accuracy: 0.982 - ETA: 31s - loss: 0.3629 - categorical_accuracy: 0.982 - ETA: 30s - loss: 0.3629 - categorical_accuracy: 0.982 - ETA: 29s - loss: 0.3628 - categorical_accuracy: 0.982 - ETA: 28s - loss: 0.3625 - categorical_accuracy: 0.982 - ETA: 29s - loss: 0.3623 - categorical_accuracy: 0.982 - ETA: 29s - loss: 0.3623 - categorical_accuracy: 0.982 - ETA: 27s - loss: 0.3622 - categorical_accuracy: 0.982 - ETA: 27s - loss: 0.3621 - categorical_accuracy: 0.982 - ETA: 27s - loss: 0.3619 - categorical_accuracy: 0.982 - ETA: 25s - loss: 0.3616 - categorical_accuracy: 0.982 - ETA: 25s - loss: 0.3616 - categorical_accuracy: 0.982 - ETA: 23s - loss: 0.3615 - categorical_accuracy: 0.982 - ETA: 22s - loss: 0.3613 - categorical_accuracy: 0.982 - ETA: 21s - loss: 0.3612 - categorical_accuracy: 0.982 - ETA: 20s - loss: 0.3610 - categorical_accuracy: 0.982 - ETA: 19s - loss: 0.3610 - categorical_accuracy: 0.982 - ETA: 18s - loss: 0.3608 - categorical_accuracy: 0.982 - ETA: 16s - loss: 0.3606 - categorical_accuracy: 0.982 - ETA: 16s - loss: 0.3606 - categorical_accuracy: 0.982 - ETA: 15s - loss: 0.3603 - categorical_accuracy: 0.982 - ETA: 14s - loss: 0.3601 - categorical_accuracy: 0.982 - ETA: 13s - loss: 0.3601 - categorical_accuracy: 0.982 - ETA: 12s - loss: 0.3599 - categorical_accuracy: 0.982 - ETA: 11s - loss: 0.3598 - categorical_accuracy: 0.982 - ETA: 10s - loss: 0.3598 - categorical_accuracy: 0.982 - ETA: 9s - loss: 0.3596 - categorical_accuracy: 0.982 - ETA: 8s - loss: 0.3595 - categorical_accuracy: 0.98 - ETA: 7s - loss: 0.3594 - categorical_accuracy: 0.98 - ETA: 6s - loss: 0.3593 - categorical_accuracy: 0.98 - ETA: 6s - loss: 0.3591 - categorical_accuracy: 0.98 - ETA: 5s - loss: 0.3590 - categorical_accuracy: 0.98 - ETA: 4s - loss: 0.3589 - categorical_accuracy: 0.98 - ETA: 3s - loss: 0.3588 - categorical_accuracy: 0.98 - ETA: 2s - loss: 0.3586 - categorical_accuracy: 0.98 - ETA: 2s - loss: 0.3585 - categorical_accuracy: 0.98 - ETA: 1s - loss: 0.3584 - categorical_accuracy: 0.98 - ETA: 0s - loss: 0.3582 - categorical_accuracy: 0.98 - 39s 239ms/step - loss: 0.3581 - categorical_accuracy: 0.9830
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 54ms/step
# Jacard Index : 0.916454408157527
# Dice Coefficient : 0.9562283075467849
# Epoch : 13
# Epoch 1/1
# 165/165 [==============================] - ETA: 40s - loss: 0.3472 - categorical_accuracy: 0.986 - ETA: 29s - loss: 0.3476 - categorical_accuracy: 0.985 - ETA: 26s - loss: 0.3484 - categorical_accuracy: 0.983 - ETA: 25s - loss: 0.3492 - categorical_accuracy: 0.983 - ETA: 24s - loss: 0.3489 - categorical_accuracy: 0.983 - ETA: 23s - loss: 0.3485 - categorical_accuracy: 0.983 - ETA: 22s - loss: 0.3488 - categorical_accuracy: 0.983 - ETA: 21s - loss: 0.3485 - categorical_accuracy: 0.984 - ETA: 20s - loss: 0.3488 - categorical_accuracy: 0.983 - ETA: 20s - loss: 0.3491 - categorical_accuracy: 0.983 - ETA: 19s - loss: 0.3496 - categorical_accuracy: 0.983 - ETA: 19s - loss: 0.3497 - categorical_accuracy: 0.983 - ETA: 19s - loss: 0.3495 - categorical_accuracy: 0.983 - ETA: 18s - loss: 0.3492 - categorical_accuracy: 0.983 - ETA: 18s - loss: 0.3493 - categorical_accuracy: 0.983 - ETA: 17s - loss: 0.3494 - categorical_accuracy: 0.983 - ETA: 17s - loss: 0.3494 - categorical_accuracy: 0.983 - ETA: 17s - loss: 0.3491 - categorical_accuracy: 0.983 - ETA: 17s - loss: 0.3491 - categorical_accuracy: 0.983 - ETA: 16s - loss: 0.3489 - categorical_accuracy: 0.983 - ETA: 16s - loss: 0.3488 - categorical_accuracy: 0.984 - ETA: 15s - loss: 0.3487 - categorical_accuracy: 0.983 - ETA: 15s - loss: 0.3486 - categorical_accuracy: 0.983 - ETA: 14s - loss: 0.3485 - categorical_accuracy: 0.984 - ETA: 13s - loss: 0.3485 - categorical_accuracy: 0.984 - ETA: 13s - loss: 0.3483 - categorical_accuracy: 0.984 - ETA: 12s - loss: 0.3482 - categorical_accuracy: 0.984 - ETA: 12s - loss: 0.3480 - categorical_accuracy: 0.984 - ETA: 11s - loss: 0.3479 - categorical_accuracy: 0.984 - ETA: 11s - loss: 0.3477 - categorical_accuracy: 0.984 - ETA: 10s - loss: 0.3477 - categorical_accuracy: 0.983 - ETA: 10s - loss: 0.3476 - categorical_accuracy: 0.983 - ETA: 9s - loss: 0.3474 - categorical_accuracy: 0.983 - ETA: 9s - loss: 0.3473 - categorical_accuracy: 0.98 - ETA: 9s - loss: 0.3472 - categorical_accuracy: 0.98 - ETA: 8s - loss: 0.3472 - categorical_accuracy: 0.98 - ETA: 8s - loss: 0.3471 - categorical_accuracy: 0.98 - ETA: 7s - loss: 0.3471 - categorical_accuracy: 0.98 - ETA: 7s - loss: 0.3470 - categorical_accuracy: 0.98 - ETA: 6s - loss: 0.3469 - categorical_accuracy: 0.98 - ETA: 6s - loss: 0.3468 - categorical_accuracy: 0.98 - ETA: 5s - loss: 0.3467 - categorical_accuracy: 0.98 - ETA: 5s - loss: 0.3466 - categorical_accuracy: 0.98 - ETA: 4s - loss: 0.3465 - categorical_accuracy: 0.98 - ETA: 4s - loss: 0.3465 - categorical_accuracy: 0.98 - ETA: 4s - loss: 0.3465 - categorical_accuracy: 0.98 - ETA: 3s - loss: 0.3464 - categorical_accuracy: 0.98 - ETA: 3s - loss: 0.3463 - categorical_accuracy: 0.98 - ETA: 2s - loss: 0.3462 - categorical_accuracy: 0.98 - ETA: 2s - loss: 0.3460 - categorical_accuracy: 0.98 - ETA: 1s - loss: 0.3459 - categorical_accuracy: 0.98 - ETA: 1s - loss: 0.3458 - categorical_accuracy: 0.98 - ETA: 0s - loss: 0.3458 - categorical_accuracy: 0.98 - ETA: 0s - loss: 0.3457 - categorical_accuracy: 0.98 - 25s 150ms/step - loss: 0.3456 - categorical_accuracy: 0.9840
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 48ms/step
# Jacard Index : 0.9125353950133559
# Dice Coefficient : 0.9538822007294437
# Epoch : 14
# Epoch 1/1
# ...
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 28ms/step
# Jacard Index : 0.9606258584742181
# Dice Coefficient : 0.979904264702086
# Epoch : 57
# Epoch 1/1
# 165/165 [==============================] - ETA: 28s - loss: 0.1226 - categorical_accuracy: 0.994 - ETA: 20s - loss: 0.1258 - categorical_accuracy: 0.995 - ETA: 17s - loss: 0.1238 - categorical_accuracy: 0.995 - ETA: 16s - loss: 0.1241 - categorical_accuracy: 0.995 - ETA: 15s - loss: 0.1240 - categorical_accuracy: 0.995 - ETA: 14s - loss: 0.1243 - categorical_accuracy: 0.994 - ETA: 13s - loss: 0.1247 - categorical_accuracy: 0.994 - ETA: 13s - loss: 0.1241 - categorical_accuracy: 0.994 - ETA: 12s - loss: 0.1243 - categorical_accuracy: 0.994 - ETA: 12s - loss: 0.1246 - categorical_accuracy: 0.994 - ETA: 11s - loss: 0.1250 - categorical_accuracy: 0.994 - ETA: 11s - loss: 0.1250 - categorical_accuracy: 0.994 - ETA: 11s - loss: 0.1248 - categorical_accuracy: 0.994 - ETA: 10s - loss: 0.1247 - categorical_accuracy: 0.994 - ETA: 10s - loss: 0.1245 - categorical_accuracy: 0.994 - ETA: 10s - loss: 0.1245 - categorical_accuracy: 0.994 - ETA: 9s - loss: 0.1244 - categorical_accuracy: 0.994 - ETA: 9s - loss: 0.1243 - categorical_accuracy: 0.99 - ETA: 9s - loss: 0.1244 - categorical_accuracy: 0.99 - ETA: 9s - loss: 0.1244 - categorical_accuracy: 0.99 - ETA: 8s - loss: 0.1247 - categorical_accuracy: 0.99 - ETA: 8s - loss: 0.1247 - categorical_accuracy: 0.99 - ETA: 8s - loss: 0.1247 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1245 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1245 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1246 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1246 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1245 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1244 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1245 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1244 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1245 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1244 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1243 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1242 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1243 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1243 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1242 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1242 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1241 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1240 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1240 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1240 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1240 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1239 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1239 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1239 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1239 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1238 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1239 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1238 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1238 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1239 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1239 - categorical_accuracy: 0.99 - 15s 89ms/step - loss: 0.1239 - categorical_accuracy: 0.9948
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 28ms/step
# Jacard Index : 0.9610442233432013
# Dice Coefficient : 0.9801230041356229
# Epoch : 58
# Epoch 1/1
# 165/165 [==============================] - ETA: 34s - loss: 0.1222 - categorical_accuracy: 0.994 - ETA: 23s - loss: 0.1206 - categorical_accuracy: 0.995 - ETA: 19s - loss: 0.1209 - categorical_accuracy: 0.995 - ETA: 17s - loss: 0.1230 - categorical_accuracy: 0.995 - ETA: 16s - loss: 0.1229 - categorical_accuracy: 0.995 - ETA: 15s - loss: 0.1225 - categorical_accuracy: 0.995 - ETA: 14s - loss: 0.1222 - categorical_accuracy: 0.995 - ETA: 13s - loss: 0.1227 - categorical_accuracy: 0.995 - ETA: 13s - loss: 0.1228 - categorical_accuracy: 0.995 - ETA: 12s - loss: 0.1223 - categorical_accuracy: 0.995 - ETA: 12s - loss: 0.1224 - categorical_accuracy: 0.995 - ETA: 12s - loss: 0.1225 - categorical_accuracy: 0.995 - ETA: 11s - loss: 0.1228 - categorical_accuracy: 0.995 - ETA: 11s - loss: 0.1230 - categorical_accuracy: 0.995 - ETA: 10s - loss: 0.1231 - categorical_accuracy: 0.995 - ETA: 10s - loss: 0.1228 - categorical_accuracy: 0.995 - ETA: 10s - loss: 0.1227 - categorical_accuracy: 0.994 - ETA: 9s - loss: 0.1229 - categorical_accuracy: 0.994 - ETA: 9s - loss: 0.1232 - categorical_accuracy: 0.99 - ETA: 9s - loss: 0.1230 - categorical_accuracy: 0.99 - ETA: 9s - loss: 0.1229 - categorical_accuracy: 0.99 - ETA: 8s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 8s - loss: 0.1228 - categorical_accuracy: 0.99 - ETA: 8s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1225 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1225 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1225 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1228 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1228 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1227 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1226 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1225 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1225 - categorical_accuracy: 0.99 - 14s 85ms/step - loss: 0.1224 - categorical_accuracy: 0.9947
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 28ms/step
# Jacard Index : 0.9606026697768835
# Dice Coefficient : 0.9798913901218336
# Epoch : 59
# Epoch 1/1
# 165/165 [==============================] - ETA: 24s - loss: 0.1249 - categorical_accuracy: 0.994 - ETA: 18s - loss: 0.1241 - categorical_accuracy: 0.994 - ETA: 16s - loss: 0.1239 - categorical_accuracy: 0.994 - ETA: 15s - loss: 0.1238 - categorical_accuracy: 0.994 - ETA: 14s - loss: 0.1230 - categorical_accuracy: 0.994 - ETA: 13s - loss: 0.1221 - categorical_accuracy: 0.994 - ETA: 13s - loss: 0.1216 - categorical_accuracy: 0.994 - ETA: 12s - loss: 0.1220 - categorical_accuracy: 0.994 - ETA: 12s - loss: 0.1217 - categorical_accuracy: 0.994 - ETA: 12s - loss: 0.1214 - categorical_accuracy: 0.994 - ETA: 11s - loss: 0.1215 - categorical_accuracy: 0.994 - ETA: 11s - loss: 0.1217 - categorical_accuracy: 0.994 - ETA: 11s - loss: 0.1218 - categorical_accuracy: 0.994 - ETA: 10s - loss: 0.1217 - categorical_accuracy: 0.994 - ETA: 10s - loss: 0.1218 - categorical_accuracy: 0.994 - ETA: 10s - loss: 0.1221 - categorical_accuracy: 0.994 - ETA: 9s - loss: 0.1221 - categorical_accuracy: 0.994 - ETA: 9s - loss: 0.1219 - categorical_accuracy: 0.99 - ETA: 9s - loss: 0.1219 - categorical_accuracy: 0.99 - ETA: 9s - loss: 0.1219 - categorical_accuracy: 0.99 - ETA: 8s - loss: 0.1218 - categorical_accuracy: 0.99 - ETA: 8s - loss: 0.1218 - categorical_accuracy: 0.99 - ETA: 8s - loss: 0.1220 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1220 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1217 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1217 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1219 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1218 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1219 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1218 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1217 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1217 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1217 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1217 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1218 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1219 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1218 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1218 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1217 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1216 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1215 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1214 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1214 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1212 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1211 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1212 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1210 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1211 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1211 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1211 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1210 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1209 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1208 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1209 - categorical_accuracy: 0.99 - 14s 84ms/step - loss: 0.1209 - categorical_accuracy: 0.9948
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 28ms/step
# Jacard Index : 0.9607596411043667
# Dice Coefficient : 0.9799751416038059
# Epoch : 60
# Epoch 1/1
# 165/165 [==============================] - ETA: 31s - loss: 0.1184 - categorical_accuracy: 0.995 - ETA: 24s - loss: 0.1193 - categorical_accuracy: 0.995 - ETA: 21s - loss: 0.1198 - categorical_accuracy: 0.995 - ETA: 20s - loss: 0.1196 - categorical_accuracy: 0.995 - ETA: 20s - loss: 0.1201 - categorical_accuracy: 0.995 - ETA: 19s - loss: 0.1203 - categorical_accuracy: 0.995 - ETA: 20s - loss: 0.1207 - categorical_accuracy: 0.995 - ETA: 19s - loss: 0.1200 - categorical_accuracy: 0.995 - ETA: 19s - loss: 0.1204 - categorical_accuracy: 0.995 - ETA: 19s - loss: 0.1199 - categorical_accuracy: 0.995 - ETA: 21s - loss: 0.1199 - categorical_accuracy: 0.995 - ETA: 20s - loss: 0.1201 - categorical_accuracy: 0.995 - ETA: 19s - loss: 0.1200 - categorical_accuracy: 0.995 - ETA: 19s - loss: 0.1200 - categorical_accuracy: 0.995 - ETA: 18s - loss: 0.1198 - categorical_accuracy: 0.995 - ETA: 18s - loss: 0.1198 - categorical_accuracy: 0.995 - ETA: 17s - loss: 0.1199 - categorical_accuracy: 0.995 - ETA: 17s - loss: 0.1197 - categorical_accuracy: 0.995 - ETA: 17s - loss: 0.1197 - categorical_accuracy: 0.995 - ETA: 17s - loss: 0.1197 - categorical_accuracy: 0.995 - ETA: 16s - loss: 0.1199 - categorical_accuracy: 0.995 - ETA: 16s - loss: 0.1198 - categorical_accuracy: 0.995 - ETA: 15s - loss: 0.1198 - categorical_accuracy: 0.995 - ETA: 15s - loss: 0.1198 - categorical_accuracy: 0.995 - ETA: 14s - loss: 0.1197 - categorical_accuracy: 0.995 - ETA: 14s - loss: 0.1197 - categorical_accuracy: 0.995 - ETA: 13s - loss: 0.1197 - categorical_accuracy: 0.995 - ETA: 13s - loss: 0.1198 - categorical_accuracy: 0.995 - ETA: 12s - loss: 0.1197 - categorical_accuracy: 0.995 - ETA: 11s - loss: 0.1196 - categorical_accuracy: 0.995 - ETA: 11s - loss: 0.1196 - categorical_accuracy: 0.995 - ETA: 10s - loss: 0.1196 - categorical_accuracy: 0.995 - ETA: 10s - loss: 0.1196 - categorical_accuracy: 0.995 - ETA: 9s - loss: 0.1195 - categorical_accuracy: 0.995 - ETA: 8s - loss: 0.1197 - categorical_accuracy: 0.99 - ETA: 8s - loss: 0.1197 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1197 - categorical_accuracy: 0.99 - ETA: 7s - loss: 0.1197 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1197 - categorical_accuracy: 0.99 - ETA: 6s - loss: 0.1197 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1196 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1194 - categorical_accuracy: 0.99 - ETA: 5s - loss: 0.1193 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1194 - categorical_accuracy: 0.99 - ETA: 4s - loss: 0.1194 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1193 - categorical_accuracy: 0.99 - ETA: 3s - loss: 0.1193 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1192 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1193 - categorical_accuracy: 0.99 - ETA: 2s - loss: 0.1193 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1193 - categorical_accuracy: 0.99 - ETA: 1s - loss: 0.1194 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1193 - categorical_accuracy: 0.99 - ETA: 0s - loss: 0.1193 - categorical_accuracy: 0.99 - 22s 134ms/step - loss: 0.1193 - categorical_accuracy: 0.9950
# 42/42 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 35ms/step
# Jacard Index : 0.9607845592668023
# Dice Coefficient : 0.9799889804536791

# %%
# from keras.utils.vis_utils import plot_model
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Save as h5 model

# %%
# note: ONNX does not work -> errors with converting to onnx 14 and below (which matlab uses)
# instead use matlab to read in h5 file
model.save('model_h5.h5')

# %%
# !pip install numpy==1.21.5 --force-reinstall
# Out:
# Collecting numpy==1.21.5
#   Downloading numpy-1.21.5-cp37-cp37m-win_amd64.whl (14.0 MB)
#      --------------------------------------- 14.0/14.0 MB 81.8 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# Successfully installed numpy-1.21.5

# %%
model_json = model.to_json()
fp = open('models\modelP_new.json','w')
fp.write(model_json)
fp.close()

# %%
import json
with open("models\modelP_new_v2.json", "w") as f:
    json.dump(json.loads(model_json), f, indent=4)

# %% [markdown]
# ## Save Last Model Weights

# %%
# model = MultiResUnet(height=352, width=400, n_channels=1)
# !pip install 'h5py==2.9.0' --force-reinstall
model.save_weights("models\modelW_last.h5")

# %% [markdown]
# ## Try on training data for sanity check

# %%
yp = model.predict(x=X_train, batch_size=1, verbose=1)
yp = np.round(yp,0)    
yp_disp = one_hot_to_seg(yp)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
plt.imshow(np.squeeze(X_train[0],axis=2))
plt.title('Input')
plt.subplot(1,3,2)

plt.imshow(one_hot_to_seg(Y_train)[0].reshape(Y_test[0].shape[0],Y_test[0].shape[1]))
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(yp_disp[0].reshape(yp[0].shape[0],yp[0].shape[1]))
plt.title('Prediction')
# Out:
# 165/165 [==============================] - ETA: 11:32: - ETA: 5:46:06 - ETA: 3:50:2 - ETA: 2:52:3 - ETA: 2:17:5 - ETA: 1:54:4 - ETA: 1:38:1 - ETA: 1:25:5 - ETA: 1:16:2 - ETA: 1:08:3 - ETA: 1:02:1 - ETA: 56:58  - ETA: 52:2 - ETA: 49:0 - ETA: 45:4 - ETA: 42:4 - ETA: 40:0 - ETA: 37:5 - ETA: 35:4 - ETA: 33:5 - ETA: 32:1 - ETA: 30:4 - ETA: 29:1 - ETA: 28:0 - ETA: 26:5 - ETA: 25:4 - ETA: 24:4 - ETA: 23:4 - ETA: 22:5 - ETA: 22:0 - ETA: 21:3 - ETA: 20:5 - ETA: 20:1 - ETA: 19:4 - ETA: 19:0 - ETA: 18:2 - ETA: 17:5 - ETA: 17:2 - ETA: 16:5 - ETA: 16:2 - ETA: 15:5 - ETA: 15:2 - ETA: 15:0 - ETA: 14:3 - ETA: 14:1 - ETA: 13:5 - ETA: 13:3 - ETA: 13:1 - ETA: 12:5 - ETA: 12:3 - ETA: 12:1 - ETA: 12:0 - ETA: 11:4 - ETA: 11:2 - ETA: 11:1 - ETA: 10:5 - ETA: 10:4 - ETA: 10:2 - ETA: 10:1 - ETA: 10:0 - ETA: 9:5 - ETA: 9: - ETA: 9: - ETA: 9: - ETA: 9: - ETA: 9: - ETA: 9: - ETA: 8: - ETA: 8: - ETA: 8: - ETA: 8: - ETA: 8: - ETA: 8: - ETA: 8: - ETA: 8: - ETA: 7: - ETA: 7: - ETA: 7: - ETA: 8: - ETA: 8: - ETA: 8: - ETA: 8: - ETA: 7: - ETA: 7: - ETA: 7: - ETA: 7: - ETA: 7: - ETA: 7: - ETA: 7: - ETA: 6: - ETA: 6: - ETA: 6: - ETA: 6: - ETA: 6: - ETA: 6: - ETA: 6: - ETA: 6: - ETA: 6: - ETA: 5: - ETA: 5: - ETA: 5: - ETA: 5: - ETA: 5: - ETA: 5: - ETA: 5: - ETA: 5: - ETA: 5: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 4: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 3: - ETA: 2: - ETA: 2: - ETA: 2: - ETA: 2: - ETA: 2: - ETA: 2: - ETA: 2: - ETA: 2: - ETA: 2: - ETA: 2: - ETA: 2: - ETA: 1: - ETA: 1: - ETA: 1: - ETA: 1: - ETA: 1: - ETA: 1: - ETA: 1: - ETA: 1: - ETA: 1: - ETA: 1: - ETA: 58s - ETA: 51 - ETA: 44 - ETA: 37 - ETA: 30 - ETA: 22 - ETA: 15 - ETA: 7 - 1295s 8s/step
# Text(0.5, 1.0, 'Prediction')

# %%
yp[0].shape[0]
# Out:
# 352

# %%
plt.imshow(yp[0][:,:,1])

# %% [markdown]
# ## Try on One Image from Test Data

# %%
yp = model.predict(x=X_test, batch_size=1, verbose=1)
yp = np.round(yp,0)    
yp_disp = one_hot_to_seg(yp)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
plt.imshow(np.squeeze(X_test[0],axis=2))
plt.title('Input')
plt.subplot(1,3,2)

plt.imshow(one_hot_to_seg(Y_test)[0].reshape(Y_test[0].shape[0],Y_test[0].shape[1]))
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(yp_disp[0].reshape(yp[0].shape[0],yp[0].shape[1]))
plt.title('Prediction')
# Out:
# 42/42 [==============================] - ETA: 12 - ETA: 7 - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 47ms/step
# Text(0.5, 1.0, 'Prediction')

# %%
img_no = 11

plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
plt.imshow(np.squeeze(X_test[img_no],axis=2))
plt.title('Input')
plt.subplot(1,3,2)

plt.imshow(one_hot_to_seg(Y_test)[img_no].reshape(Y_test[0].shape[0],Y_test[0].shape[1]))
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(yp_disp[img_no].reshape(yp[0].shape[0],yp[0].shape[1]))
plt.title('Prediction')
# Out:
# Text(0.5, 1.0, 'Prediction')

# %% [markdown]
# ## Try on never seen test data

# %% [markdown]
# ### Preprocess Part 1

# %%
X_test_test = []
Y_test_test = []

img = cv2.imread("E:\YKL\Thorlabs VSCAN Labeling\scan27\VSCAN_0027_190.png", cv2.IMREAD_GRAYSCALE)

#         print('E:\YKL\Thorlabs VSCAN Labeling\scan30\{}'.format(img_fl))
resized_img = cv2.equalizeHist(np.clip(cv2.resize(img,(400, 352), interpolation = cv2.INTER_NEAREST),0,255))
resized_denoised_img = cv2.fastNlMeansDenoising(resized_img,10,7,21)

X_test_test.append(resized_denoised_img)

msk = cv2.imread("E:\YKL\Thorlabs VSCAN Labeling\scan27\LabelingProject\GroundTruthProject\PixelLabelData\Label_1_VSCAN_0027_190.png", cv2.IMREAD_GRAYSCALE)
resized_msk = np.clip(cv2.resize(msk,(400, 352), interpolation = cv2.INTER_NEAREST),0,4)

# additional post processing for one hot encoding mask
resized_msk[resized_msk==0] = 6;
resized_msk_one_hot = np.zeros((resized_msk.shape[0], resized_msk.shape[1], n_classes))
for i, unique_value in enumerate(np.unique(resized_msk)):
    resized_msk_one_hot[:, :, i][resized_msk == unique_value] = 1

Y_test_test.append(resized_msk_one_hot)

# %%
plt.imshow(Y_test_test[0][:,:,2])

# %% [markdown]
# ### Preprocess part 2

# %%
X_test_test = np.array(X_test_test)
X_test_test = X_test_test[:, :, :, np.newaxis]
X_test_test = X_test_test / 255

# %% [markdown]
# ### Prediction

# %%
yp_test = model.predict(x=X_test_test, batch_size=1, verbose=1)
yp_test = np.round(yp_test,0)    
yp_test_disp = one_hot_to_seg(yp_test)
# Out:
# 1/1 [==============================] - 7s 7s/step

# %% [markdown]
# ### Show result

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
plt.imshow(np.squeeze(X_test_test[0],axis=2))
plt.title('Input')
plt.subplot(1,3,2)
plt.imshow(yp_test_disp[0].reshape(yp[0].shape[0],yp[0].shape[1]))
plt.title('Prediction')
# Out:
# Text(0.5, 1.0, 'Prediction')
